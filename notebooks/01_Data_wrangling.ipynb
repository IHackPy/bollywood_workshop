# %% [markdown]
# # Part I: Loading, exploring and cleaning data
#
# ![](img/cleaning.jpeg)
#
#
# Data has been obtained from the Internet movie database:
# - https://www.imdb.com/search/title?title_type=feature&release_date=1970-01-01,&countries=in&languages=hi&page=1
#
# In this section we'll learn:
# - How to load data from different sources
# - How to combine data from different sources
# - Exploring the content of the loaded data: the raw data, and statistics and aggregates
# - Cleaning the data, removing wrong values, formatting it in a useful representation, dealing with missing values...

# %%
import os

MOVIES_LIST_FNAME = os.path.join('data', 'movies_from_list.csv.gz')
MOVIES_DETAIL_FNAME = os.path.join('data', 'movies_from_detail.json.bz2')

# %% [markdown]
# ### Load data
#
# pandas supports many formats for loading data. You can see most of them in:
# - https://pandas.pydata.org/pandas-docs/stable/api.html#input-output
#
# Also, data can be imported into pandas from Python objects (list, dict, tuple...) with the `DataFrame` and `Series` constructor.
#
# **EXERCISE:** Load the datasets defined in `MOVIES_LIST_FNAME` and `MOVIES_DETAIL_FNAME` into pandas `DataFrame` objects.

# %%
import pandas as pd

# %% [markdown]
# ### Exploring
#
# There are many ways to explore the data in a pandas container. Try calling on them the next methods: `.head()`, `.tail()`, `.head().T`, `.describe()` and `.info()`.

# %%
movies_list = pd.read_csv(MOVIES_LIST_FNAME, compression='gzip',sep = ' ', error_bad_lines=False)
# Out:
# b'Skipping line 4: expected 24 fields, saw 39\nSkipping line 7: expected 24 fields, saw 28\nSkipping line 8: expected 24 fields, saw 33\nSkipping line 9: expected 24 fields, saw 38\nSkipping line 11: expected 24 fields, saw 34\nSkipping line 12: expected 24 fields, saw 35\nSkipping line 13: expected 24 fields, saw 28\nSkipping line 15: expected 24 fields, saw 30\nSkipping line 16: expected 24 fields, saw 34\nSkipping line 17: expected 24 fields, saw 36\nSkipping line 18: expected 24 fields, saw 26\nSkipping line 19: expected 24 fields, saw 33\nSkipping line 20: expected 24 fields, saw 25\nSkipping line 22: expected 24 fields, saw 29\nSkipping line 24: expected 24 fields, saw 41\nSkipping line 27: expected 24 fields, saw 37\nSkipping line 28: expected 24 fields, saw 35\nSkipping line 29: expected 24 fields, saw 42\nSkipping line 30: expected 24 fields, saw 30\nSkipping line 31: expected 24 fields, saw 35\nSkipping line 34: expected 24 fields, saw 40\nSkipping line 35: expected 24 fields, saw 28\nSkipping line 37: expected 24 fields, saw 40\nSkipping line 38: expected 24 fields, saw 30\nSkipping line 39: expected 24 fields, saw 39\nSkipping line 42: expected 24 fields, saw 26\nSkipping line 43: expected 24 fields, saw 27\nSkipping line 45: expected 24 fields, saw 38\nSkipping line 46: expected 24 fields, saw 25\nSkipping line 47: expected 24 fields, saw 39\nSkipping line 49: expected 24 fields, saw 25\nSkipping line 50: expected 24 fields, saw 38\nSkipping line 51: expected 24 fields, saw 29\nSkipping line 53: expected 24 fields, saw 26\nSkipping line 55: expected 24 fields, saw 33\nSkipping line 57: expected 24 fields, saw 38\nSkipping line 58: expected 24 fields, saw 33\nSkipping line 64: expected 24 fields, saw 46\nSkipping line 65: expected 24 fields, saw 42\nSkipping line 66: expected 24 fields, saw 41\nSkipping line 67: expected 24 fields, saw 47\nSkipping line 68: expected 24 fields, saw 36\nSkipping line 69: expected 24 fields, saw 29\nSkipping line 70: expected 24 fields, saw 33\nSkipping line 71: expected 24 fields, saw 36\nSkipping line 72: expected 24 fields, saw 25\nSkipping line 73: expected 24 fields, saw 33\nSkipping line 74: expected 24 fields, saw 37\nSkipping line 75: expected 24 fields, saw 27\nSkipping line 78: expected 24 fields, saw 29\nSkipping line 81: expected 24 fields, saw 31\nSkipping line 82: expected 24 fields, saw 39\nSkipping line 83: expected 24 fields, saw 34\nSkipping line 84: expected 24 fields, saw 37\nSkipping line 86: expected 24 fields, saw 25\nSkipping line 88: expected 24 fields, saw 31\nSkipping line 91: expected 24 fields, saw 35\nSkipping line 94: expected 24 fields, saw 26\nSkipping line 96: expected 24 fields, saw 31\nSkipping line 97: expected 24 fields, saw 42\nSkipping line 98: expected 24 fields, saw 32\nSkipping line 102: expected 24 fields, saw 39\nSkipping line 104: expected 24 fields, saw 44\nSkipping line 106: expected 24 fields, saw 25\nSkipping line 108: expected 24 fields, saw 29\nSkipping line 109: expected 24 fields, saw 39\nSkipping line 111: expected 24 fields, saw 36\nSkipping line 115: expected 24 fields, saw 30\nSkipping line 116: expected 24 fields, saw 34\nSkipping line 117: expected 24 fields, saw 25\nSkipping line 118: expected 24 fields, saw 28\nSkipping line 121: expected 24 fields, saw 26\nSkipping line 122: expected 24 fields, saw 37\nSkipping line 123: expected 24 fields, saw 36\nSkipping line 124: expected 24 fields, saw 26\nSkipping line 126: expected 24 fields, saw 35\nSkipping line 129: expected 24 fields, saw 36\nSkipping line 132: expected 24 fields, saw 43\nSkipping line 135: expected 24 fields, saw 35\nSkipping line 137: expected 24 fields, saw 31\nSkipping line 138: expected 24 fields, saw 39\nSkipping line 140: expected 24 fields, saw 41\nSkipping line 143: expected 24 fields, saw 43\nSkipping line 145: expected 24 fields, saw 26\nSkipping line 146: expected 24 fields, saw 25\nSkipping line 148: expected 24 fields, saw 25\nSkipping line 149: ex ...

# %%
movies_list.head()
# Out:
#                                                                                                                                                                                                                                             imdb_id;title;summary;year;rating;gross
# tt5474036;Husband   Material;The film              is      a            love       story  set        in       Punjab              where   Abhishek Bachchan, Taapsee Pannu,          and Vicky Kaushal          will be  seen in  prominent                     roles.;2018;7.0;5.0
# tt5970844;Thugs     of           Hindostan;;2018;; NaN     NaN          NaN        NaN    NaN        NaN      NaN                 NaN     NaN      NaN       NaN     NaN             NaN NaN   NaN              NaN  NaN NaN  NaN NaN                                           NaN
# tt7720922;Batti     Gul          Meter             Chalu;A social       movie      about  escalating electric bills.;2018;6.4;1.0 NaN     NaN      NaN       NaN     NaN             NaN NaN   NaN              NaN  NaN NaN  NaN NaN                                           NaN
# tt5080556;2.0;Dr.   Vaseegaran   is                forced  to           reassemble Chitti in         order    to                  stop    a        deadly    winged  monster.;2018;; NaN NaN   NaN              NaN  NaN NaN  NaN NaN                                           NaN
# tt6923462;Manto;The film         is                a       biographical account    of     writer     Saadat   Hasan               Manto's life     and       is      set             in  1940s India.;2018;8.0; NaN  NaN NaN  NaN NaN                                           NaN

# %%
movies_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 5451 entries, (tt5474036;Husband, Material;The, film, is, a, love, story, set, in, Punjab, where, Abhishek, Bachchan,, Taapsee, Pannu,, and, Vicky, Kaushal, will, be, seen, in, prominent) to (tt9060700;The, Check, Post;;2019;;, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan)
# Data columns (total 1 columns):
# imdb_id;title;summary;year;rating;gross    89 non-null object
# dtypes: object(1)
# memory usage: 469.2+ KB

# %%
movies_list.shape
# Out:
# (5451, 1)

# %% [markdown]
# ### Combining datasets
#
# pandas provides different ways to combine datasets into one. For people familiar with SQL, the functionality is similar to `JOIN` and `UNION`.
#
# Documentation can be found here:
# - https://pandas.pydata.org/pandas-docs/stable/merging.html
#
# In the case of adding columns of one `DataFrame` to another, we can use `DataFrame.join` (equivalent to SQL `JOIN`). Documentation can be found here:
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.join.html
#
# **EXERCISE:** In this case we want to join the two previously loaded `DataFrame` objects into one. To make sure we implement it correctly, we need to see the check the shape of both `DataFrame` with the method `.shape`, and also check the shape of the resulting `DataFrame` to make sure we are not duplicating or missing rows. When joining, the important parameters are `on` and `how`.

# %%
movies_detail = pd.read_json(MOVIES_DETAIL_FNAME)

# %%
movies_detail
# Out:
#                                                    storyline  \
# tt0065467  Deep Sharma lives a very poor lifestyle with h...
# tt0065612  A Teacher from Siddharth College, Balraj Dutt ...
# tt0065758  Raja Sahib is a pious and good-hearted man. Af...
# tt0065764  Delhi-based Kamla lives a wealthy lifestyle al...
# tt0065882  Ajit lives a wealthy lifestyle along with his ...
# tt0065903  Amar Doraiswamy is the only child of multi-mil...
# tt0065927                                               None
# tt0065936  Madhu was engaged to somebody. She ran away to...
# tt0066070  Raju is a joker, a clown. It is what he is and...
# tt0066241  Ramdev Bakshi is the only son of widower and f...
# tt0066514  A woman waits for her truck driver husband, ev...
# tt0066589  An honest and patriotic young man learns that ...
# tt0066758  A village woman abandoned by her husband is fo...
# tt0066763  A melodramatic tale of a man with a terminal d...
# tt0066766  Rajoo (Rajesh Khanna) and Sheetal (Hema Malini...
# tt0066787  Aashad Ka Ek Din is an adaptation of the play ...
# tt0066888  Sunita is a young woman who ends up married to...
# tt0067000                     I am use data do not copyright
# tt0067164  Kusum is a quiet and simple school girl who is...
# tt0067183  In the background of the rise of the Internati...
# tt0067403  Lalita lives with her widowed mother in a smal...
# tt0067421  Anandi Devi is an old widow living in her vill...
# tt0067478  Anoop (Dharmendra) is a struggling writer. One...
# tt0067553  Rajjoo alias Rajni lives in a small village in...
# tt0067555  Kumar Sen is an artist of eminence, a talented...
# tt0067636  Although well qualified, Ram Chand is unable t...
# tt0067651  Dharmendra plays Deepak, an honest, hard worki...
# tt0067668  Reshma and Shera belong to rival families.They...
# tt0067742  While returning from Army Base, Captain Ajit K...
# tt0067840  Dr. Anand Kumar attains his degree in medicine...
# ...                                                      ...
# tt8983228                                               None
# tt8984572                                               None
# tt8992946  A young female astronaut, who joins a recluse ...
# tt8998738  A girl and a guy- it's love, it's real, it's r...
# tt9000388  Four women from Delhi, NCR and Gurgaon, tired ...
# tt9007142  Set in the city of Mumbai, The Dark Side of Li...
# tt9014832                                               None
# tt9015154                                               None
# tt9030418                                               None
# tt9033366                                               None
# tt9033670  Musam Ikrar ke - Do pal Pyaar ke is a 2018 mus...
# tt9033988  Narendra Upadhyay Wakes up and finds himself b...
# tt9041222                                               None
# tt9042282  Neha suspects Vikram of infidelity after havin...
# tt9042528                                               None
# tt9043760                                               None
# tt9044000  Eegi Khongul is a Manipuri feature film highli...
# tt9046206                                               None
# tt9052870                                               None
# tt9052936                                               None
# tt9052942                                               None
# tt9052946                                               None
# tt9052958          Movie is adaptation of the epic Ramayana.
# tt9052960                                               None
# tt9052964                                               None
# tt9053392                                               None
# tt9055312  This movie is about a phony, irresponsible and...
# tt9056988  Later they realise that the game has turned ab...
# tt9059202                                               None
# tt9060700                                               None
#
#                                                        photo  \
# tt0065467  https://m.media-amazon.com/images/M/MV5BYWNlNj...
# tt0065612                                               None
# tt0065758  https://m.media-amazon.com/images/M/MV5BMTc5Nz...
# tt0065764  https://m.media-amazon.com/images/M/MV5BNjg2Nz...
# tt0065882                                               None
# tt0065903                                               None
# tt0065927  https://m.media-amazon.com/images/M/MV5BZmQ4Mm...
# tt0065936  https://m.media-amazon.com/images/M/MV5BNDczOG...
# tt0066070  https://m.media-amazon.com/images/M/MV5BODM2ND...
# tt0066241  https://m.media-amazon.com/images/M/MV5BMzJlMW...
# tt0066514  https://m.media-amazon.com/images/M/MV5BMGRlOG...
# tt0066589                                               None
# tt0066758  https://m.media-amazon.com/images/M/MV5BMTM4Nz...
# tt0066763  https://m.media-amazon.com/images/M/MV5BZTYxNT...
# tt0066766  https://m.media-amazon.com/images/M/MV5BNzVlNG...
# tt0066787  https://m.media-amazon.com/images/M/MV5BMmE0Ym...
# tt0066888  https://m.media-amazon.com/images/M/MV5BY2Y4OD...
# tt0067000                                               None
# tt0067164  https://m.media-amazon.com/images/M/MV5BMTcyND...
# tt0067183  https://m.media-amazon.com/images/M/MV5BNmM5ZT...
# tt0067403  https://m.media-amazon.com/images/M/MV5BY2M0NT...
# tt0067421  https://m.media-amazon.com/images/M/MV5BMTk5NT...
# tt0067478  https://m.media-amazon.com/images/M/MV5BNDIyNT...
# tt0067553  https://m.media-amazon.com/images/M/MV5BMTliMT...
# tt0067555  https://m.media-amazon.com/images/M/MV5BYTQ1NW...
# tt0067636  https://m.media-amazon.com/images/M/MV5BYjlkYT...
# tt0067651                                               None
# tt0067668  https://m.media-amazon.com/images/M/MV5BMTY4Nz...
# tt0067742  https://m.media-amazon.com/images/M/MV5BNDFjMj...
# tt0067840  https://m.media-amazon.com/images/M/MV5BY2UwMD...
# ...                                                      ...
# tt8983228                                               None
# tt8984572                                               None
# tt8992946                                               None
# tt8998738                                               None
# tt9000388  https://m.media-amazon.com/images/M/MV5BZjhjZD...
# tt9007142  https://m.media-amazon.com/images/M/MV5BNjIyZG...
# tt9014832                                               None
# tt9015154  https://m.media-amazon.com/images/M/MV5BNzlhM2...
# tt9030418  https://m.media-amazon.com/images/M/MV5BYmRmN2...
# tt9033366  https://m.media-amazon.com/images/M/MV5BNWZjN2...
# tt9033670  https://m.media-amazon.com/images/M/MV5BNWRiMz...
# tt9033988                                               None
# tt9041222                                               None
# tt9042282  https://m.media-amazon.com/images/M/MV5BMzFhZj...
# tt9042528                                               None
# tt9043760                                               None
# tt9044000  https://m.media-amazon.com/images/M/MV5BNmYwMz...
# tt9046206  https://m.media-amazon.com/images/M/MV5BNWFiMG...
# tt9052870                                               None
# tt9052936                                               None
# tt9052942                                               None
# tt9052946                                               None
# tt9052958                                               None
# tt9052960                                               None
# tt9052964                                               None
# tt9053392                                               None
# tt9055312  https://m.media-amazon.com/images/M/MV5BZTM3ZD...
# tt9056988                                               None
# tt9059202                                               None
# tt9060700                                               None
#
#                         release_date  country                   language  \
# tt0065467                       None  [India]                    [Hindi]
# tt0065612                       None  [India]                    [Hindi]
# tt0065758                       None  [India]                    [Hindi]
# tt0065764                       None  [India]                    [Hindi]
# tt0065882                       None  [India]                    [Hindi]
# tt0065903                       None  [India]                    [Hindi]
# tt0065927                       None  [India]                    [Hindi]
# tt0065936   19 March 1980 (Portugal)  [India]                    [Hindi]
# tt0066070   18 December 1970 (India)  [India]  [Hindi, Russian, English]
# tt0066241    28 January 1970 (India)  [India]                    [Hindi]
# tt0066514                       None  [India]                    [Hindi]
# tt0066589                       None  [India]                    [Hindi]
# tt0066758    28 January 1972 (India)  [India]                    [Hindi]
# tt0066763      12 March 1971 (India)  [India]                    [Hindi]
# tt0066766                       None  [India]                    [Hindi]
# tt0066787                       None  [India]                    [Hindi]
# tt0066888                       None  [India]                    [Hindi]
# tt0067000                       None  [India]                    [Hindi]
# tt0067164     1 January 1971 (India)  [India]                    [Hindi]
# tt0067183    9 December 1971 (India)  [India]                    [Hindi]
# tt0067403                       None  [India]                    [Hindi]
# tt0067421                       None  [India]                    [Hindi]
# tt0067478                       None  [India]                    [Hindi]
# tt0067553                       None  [India]                    [Hindi]
# tt0067555        9 July 1971 (India)  [India]                    [Hindi]
# tt0067636        14 May 1971 (India)  [India]                    [Hindi]
# tt0067651     12 August 1971 (India)  [India]                    [Hindi]
# tt0067668       23 July 1971 (India)  [India]                    [Hindi]
# tt0067742   25 April 1981 (Portugal)  [India]                    [Hindi]
# tt0067840        13 May 1971 (India)  [India]                    [Hindi]
# ...                              ...      ...                        ...
# tt8983228               2019 (India)  [India]                    [Hindi]
# tt8984572                       None  [India]                    [Hindi]
# tt8992946                       None  [India]                    [Hindi]
# tt8998738                       None  [India]                    [Hindi]
# tt9000388                       None  [India]                    [Hindi]
# tt9007142    19 October 2018 (India)  [India]                    [Hindi]
# tt9014832               2019 (India)  [India]                    [Hindi]
# tt9015154    12 January 2017 (India)  [India]                    [Hindi]
# tt9030418                       None  [India]                    [Hindi]
# tt9033366    19 January 2018 (India)  [India]                    [Hindi]
# tt9033670    2 November 2018 (India)  [India]                    [Hindi]
# tt9033988                       None  [India]                    [Hindi]
# tt9041222               1977 (India)  [India]           [Marathi, Hindi]
# tt9042282   19 December 2011 (India)  [India]                    [Hindi]
# tt9042528                       None  [India]                    [Hindi]
# tt9043760                       None  [India]                    [Hindi]
# tt9044000   22 November 2017 (India)  [India]                    [Hindi]
# tt9046206   28 December 2018 (India)  [India]                    [Hindi]
# tt9052870     30 August 2019 (India)  [India]                    [Hindi]
# tt9052936               2019 (India)  [India]                    [Hindi]
# tt9052942               2019 (India)  [India]                    [Hindi]
# tt9052946                       None  [India]                    [Hindi]
# tt9052958               2019 (India)  [India]                    [Hindi]
# tt9052960               2019 (India)  [India]                    [Hindi]
# tt9052964               2018 (India)  [India]                    [Hindi]
# tt9053392                       None  [India]                    [Hindi]
# tt9055312    26 October 2018 (India)  [India]                    [Hindi]
# tt9056988               2018 (India)  [India]                    [Hindi]
# tt9059202  30 September 2018 (India)  [India]                    [Hindi]
# tt9060700      February 2019 (India)  [India]                    [Hindi]
#
#                                                  genres            color  \
# tt0065467                       [Action, Drama, Family]            Color
# tt0065612                               [Drama, Family]            Color
# tt0065758                      [Drama, Family, Musical]            Color
# tt0065764             [Action, Crime, Musical, Romance]            Color
# tt0065882                        [Action, Crime, Drama]  Black and White
# tt0065903                                     [Romance]            Color
# tt0065927                               [Action, Crime]            Color
# tt0065936             [Drama, Romance, Musical, Family]            Color
# tt0066070                               [Comedy, Drama]             None
# tt0066241             [Action, Drama, Musical, Romance]            Color
# tt0066514                                       [Drama]            Color
# tt0066589           [Musical, Adventure, Drama, Family]            Color
# tt0066758                     [Drama, Musical, Romance]            Color
# tt0066763                                       [Drama]            Color
# tt0066766                              [Drama, Romance]            Color
# tt0066787                            [Biography, Drama]  Black and White
# tt0066888  [Action, Comedy, Musical, Romance, Thriller]            Color
# tt0067000                                          None            Color
# tt0067164                       [Drama, Comedy, Family]            Color
# tt0067183                              [Drama, Musical]            Color
# tt0067403                             [Family, Romance]            Color
# tt0067421                                       [Drama]            Color
# tt0067478                              [Drama, Musical]            Color
# tt0067553                               [Drama, Family]            Color
# tt0067555                           [Romance, Thriller]            Color
# tt0067636              [Comedy, Drama, Family, Romance]            Color
# tt0067651                   [Action, Musical, Thriller]            Color
# tt0067668                     [Drama, Musical, Romance]            Color
# tt0067742                   [Mystery, Musical, Romance]            Color
# tt0067840                              [Drama, Romance]            Color
# ...                                                 ...              ...
# tt8983228                                   [Biography]            Color
# tt8984572                                       [Drama]            Color
# tt8992946                             [Fantasy, Sci-Fi]            Color
# tt8998738                              [Drama, Romance]            Color
# tt9000388                                       [Drama]            Color
# tt9007142                                       [Drama]            Color
# tt9014832                                       [Drama]            Color
# tt9015154                                       [Drama]            Color
# tt9030418                              [Drama, Romance]            Color
# tt9033366                                   [Biography]            Color
# tt9033670                                       [Drama]            Color
# tt9033988                                    [Thriller]            Color
# tt9041222                             [Family, Mystery]            Color
# tt9042282                                    [Thriller]            Color
# tt9042528                                       [Drama]            Color
# tt9043760                                     [Romance]            Color
# tt9044000                                       [Crime]            Color
# tt9046206                                       [Drama]            Color
# tt9052870                                       [Drama]            Color
# tt9052936                                    [Thriller]            Color
# tt9052942                                          None            Color
# tt9052946                                          None            Color
# tt9052958                                          None            Color
# tt9052960                                          None            Color
# tt9052964                                      [Comedy]            Color
# tt9053392                                      [Action]            Color
# tt9055312                       [Comedy, Drama, Family]            Color
# tt9056988                                      [Horror]            Color
# tt9059202                                       [Drama]            Color
# tt9060700                                       [Drama]            Color
#
#            runtime     certificate  \
# tt0065467     None            None
# tt0065612     None            None
# tt0065758     None            None
# tt0065764     None            None
# tt0065882     None            None
# tt0065903     None            None
# tt0065927     None            None
# tt0065936     None  Not Rated|\n »
# tt0066070  224 min               »
# tt0066241  192 min            None
# tt0066514  110 min       Not Rated
# tt0066589     None            None
# tt0066758  143 min  Not Rated|\n »
# tt0066763  122 min  Not Rated|\n »
# tt0066766  166 min              PG
# tt0066787  114 min       Not Rated
# tt0066888  161 min            None
# tt0067000  141 min            None
# tt0067164  121 min  Not Rated|\n »
# tt0067183  149 min         15|\n »
# tt0067403     None            None
# tt0067421  164 min  Not Rated|\n »
# tt0067478  151 min         PG|\n »
# tt0067553     None         15|\n »
# tt0067555   93 min              PG
# tt0067636  150 min  Not Rated|\n »
# tt0067651     None            None
# tt0067668  158 min         15|\n »
# tt0067742  164 min            None
# tt0067840  175 min              12
# ...            ...             ...
# tt8983228     None            None
# tt8984572     None            None
# tt8992946  105 min            None
# tt8998738  106 min            None
# tt9000388     None            None
# tt9007142  125 min            None
# tt9014832     None            None
# tt9015154     None            None
# tt9030418     None            None
# tt9033366     None            None
# tt9033670     None            None
# tt9033988     None            None
# tt9041222     None            None
# tt9042282   75 min            None
# tt9042528   60 min            None
# tt9043760     None            None
# tt9044000   39 min            None
# tt9046206     None            None
# tt9052870     None            None
# tt9052936     None            None
# tt9052942     None            None
# tt9052946     None            None
# tt9052958     None            None
# tt9052960     None            None
# tt9052964     None            None
# tt9053392     None            None
# tt9055312     None            None
# tt9056988     None            None
# tt9059202   65 min            None
# tt9060700   90 min            None
#
#                                                production_co  rate  \
# tt0065467                                                 []   6.1
# tt0065612                                               None   7.4
# tt0065758                                                 []   6.0
# tt0065764                                                 []   7.4
# tt0065882                                                 []   NaN
# tt0065903                                                 []   7.0
# tt0065927                                                 []   4.8
# tt0065936                                     [Shakti Films]   7.2
# tt0066070                                                 []   8.0
# tt0066241                                                 []   6.8
# tt0066514                                                 []   6.8
# tt0066589                                                 []   6.2
# tt0066758                                     [Shakti Films]   8.2
# tt0066763                                                 []   8.8
# tt0066766                                                 []   6.8
# tt0066787                                               None   6.9
# tt0066888                              [Nasir Hussain Films]   6.9
# tt0067000                                               None   6.7
# tt0067164                                                 []   7.3
# tt0067183                                                 []   7.3
# tt0067403                                                 []   7.4
# tt0067421                                                 []   7.6
# tt0067478                                                 []   6.9
# tt0067553                                                 []   6.4
# tt0067555                                                 []   6.9
# tt0067636                                               None   6.3
# tt0067651                                                 []   5.9
# tt0067668                                                 []   6.7
# tt0067742                      [Subodh Mukherji Productions]   6.9
# tt0067840                                               None   7.3
# ...                                                      ...   ...
# tt8983228                                                 []   NaN
# tt8984572                                                 []   NaN
# tt8992946                                               None   NaN
# tt8998738                                               None   NaN
# tt9000388                                                 []   NaN
# tt9007142                                                 []   NaN
# tt9014832                                                 []   NaN
# tt9015154                                                 []   NaN
# tt9030418                     [K. K. Films Production House]   NaN
# tt9033366                                               None   NaN
# tt9033670                                                 []   NaN
# tt9033988           [AVA Film Productions, E4 Entertainment]   NaN
# tt9041222                                               None   NaN
# tt9042282                                                 []   NaN
# tt9042528                                                 []   NaN
# tt9043760                                                 []   NaN
# tt9044000                                                 []   NaN
# tt9046206                                               None   NaN
# tt9052870                                                 []   NaN
# tt9052936                                                 []   NaN
# tt9052942                                                 []   NaN
# tt9052946                                               None   NaN
# tt9052958                                                 []   NaN
# tt9052960                                                 []   NaN
# tt9052964                                                 []   NaN
# tt9053392                                               None   NaN
# tt9055312         [Pisceann Pictures, Royal Life Production]   NaN
# tt9056988                                                 []   NaN
# tt9059202                                                 []  10.0
# tt9060700  [Golden Triangle Charity Trust, Sylph Producti...   NaN
#
#           num_ratings                                      plot_keywords  \
# tt0065467          15                                               None
# tt0065612          29                                           [remake]
# tt0065758          30                                               None
# tt0065764          81                                               None
# tt0065882        None                                               None
# tt0065903          36                                               None
# tt0065927          25                                               None
# tt0065936         738             [train, friend, widow, holi, betrayal]
# tt0066070       4,052    [circus, joker, philosophy, entertainer, clown]
# tt0066241         167       [village, hay, butterfly net, disguise, spy]
# tt0066514         149                                               None
# tt0066589          18                                               None
# tt0066758       1,241  [prostitute, bangles, female protagonist, affe...
# tt0066763      20,889  [doctor, lymphosarcoma, tragic past, dark past...
# tt0066766         219             [boy, teacher, suicide, widower, love]
# tt0066787          34                                               None
# tt0066888         219  [gypsy, murder, knife throwing, unrequited lov...
# tt0067000          10                                               None
# tt0067164         808   [girl, actor, schoolgirl, movie fan, film shoot]
# tt0067183         668  [kathmandu nepal, 1970s, hare krishna, false a...
# tt0067403          45                                               None
# tt0067421         416           [city, village, compassion, widow, maid]
# tt0067478          76        [writer, novel, lynch mob, jail, injustice]
# tt0067553          46                                               None
# tt0067555         149            [love, court, sculptor, murder, lawyer]
# tt0067636          65                                               None
# tt0067651          30        [shot in the back, marriage, fight, murder]
# tt0067668         158   [forbidden love, sacrifice, oath, goddess, fair]
# tt0067742         116  [twin sister, captain, colonel, depression, dr...
# tt0067840         190   [doctor, actress, village, alcoholic, pregnancy]
# ...               ...                                                ...
# tt8983228        None                                               None
# tt8984572        None                                               None
# tt8992946        None                                               None
# tt8998738        None                                               None
# tt9000388        None                                               None
# tt9007142        None                                               None
# tt9014832        None                                               None
# tt9015154        None                                               None
# tt9030418        None                           [anthology, modern love]
# tt9033366        None                                               None
# tt9033670        None                                               None
# tt9033988        None                                               None
# tt9041222        None                                               None
# tt9042282        None                                               None
# tt9042528        None                                               None
# tt9043760        None                                               None
# tt9044000        None                                               None
# tt9046206        None                                               None
# tt9052870        None                                               None
# tt9052936        None                                               None
# tt9052942        None                                               None
# tt9052946        None                                               None
# tt9052958        None                                               None
# tt9052960        None                                               None
# tt9052964        None                                               None
# tt9053392        None                                               None
# tt9055312        None                                               None
# tt9056988        None                                            [hindi]
# tt9059202           5                                               None
# tt9060700        None                                               None
#
#                                                         cast
# tt0065467  [{'imdb_id': 'nm0004570', 'name': 'Sunil Dutt'...
# tt0065612  [{'imdb_id': 'nm0004570', 'name': 'Sunil Dutt'...
# tt0065758  [{'imdb_id': 'nm0904537', 'name': 'Vyjayanthim...
# tt0065764  [{'imdb_id': 'nm0006348', 'name': 'Rajendra Ku...
# tt0065882  [{'imdb_id': 'nm0802107', 'name': 'Dara Singh'...
# tt0065903  [{'imdb_id': 'nm0623321', 'name': 'Sadhana', '...
# tt0065927  [{'imdb_id': 'nm0004570', 'name': 'Sunil Dutt'...
# tt0065936  [{'imdb_id': 'nm0004435', 'name': 'Rajesh Khan...
# tt0066070  [{'imdb_id': 'nm0006370', 'name': 'Manoj Kumar...
# tt0066241  [{'imdb_id': 'nm0007147', 'name': 'Dev Anand',...
# tt0066514  [{'imdb_id': 'nm1388379', 'name': 'Savita Baja...
# tt0066589  [{'imdb_id': 'nm0638295', 'name': 'Nutan', 'li...
# tt0066758  [{'imdb_id': 'nm0004435', 'name': 'Rajesh Khan...
# tt0066763  [{'imdb_id': 'nm0004435', 'name': 'Rajesh Khan...
# tt0066766  [{'imdb_id': 'nm0004433', 'name': 'Shammi Kapo...
# tt0066787  [{'imdb_id': 'nm0045119', 'name': 'Aruna Irani...
# tt0066888  [{'imdb_id': 'nm0661239', 'name': 'Asha Parekh...
# tt0067000  [{'imdb_id': 'nm0013026', 'name': 'Jalal Agha'...
# tt0067164  [{'imdb_id': 'nm0004429', 'name': 'Dharmendra'...
# tt0067183  [{'imdb_id': 'nm0023868', 'name': 'Zeenat Aman...
# tt0067403  [{'imdb_id': 'nm0004435', 'name': 'Rajesh Khan...
# tt0067421  [{'imdb_id': 'nm0474932', 'name': 'Meena Kumar...
# tt0067478  [{'imdb_id': 'nm0004429', 'name': 'Dharmendra'...
# tt0067553  [{'imdb_id': 'nm0004564', 'name': 'Hema Malini...
# tt0067555  [{'imdb_id': 'nm0632615', 'name': 'Navin Nisch...
# tt0067636  [{'imdb_id': 'nm0802366', 'name': 'Mala Sinha'...
# tt0067651  [{'imdb_id': 'nm0004429', 'name': 'Dharmendra'...
# tt0067668  [{'imdb_id': 'nm0716851', 'name': 'Waheeda Reh...
# tt0067742  [{'imdb_id': 'nm0004434', 'name': 'Shashi Kapo...
# tt0067840  [{'imdb_id': 'nm0007147', 'name': 'Dev Anand',...
# ...                                                      ...
# tt8983228  [{'imdb_id': 'nm0000821', 'name': 'Amitabh Bac...
# tt8984572  [{'imdb_id': 'nm1203651', 'name': 'Rohit Nayya...
# tt8992946  [{'imdb_id': 'nm4975360', 'name': 'Shweta Trip...
# tt8998738  [{'imdb_id': 'nm6109850', 'name': 'Khushboo Up...
# tt9000388  [{'imdb_id': 'nm3492981', 'name': 'Shalini Vat...
# tt9007142  [{'imdb_id': 'nm10125857', 'name': 'Avii', 'li...
# tt9014832                                                 []
# tt9015154  [{'imdb_id': 'nm10130020', 'name': 'Durvesh Ar...
# tt9030418  [{'imdb_id': 'nm10137332', 'name': 'Neha Bose'...
# tt9033366  [{'imdb_id': 'nm10139270', 'name': 'Sibu Giri'...
# tt9033670  [{'imdb_id': 'nm9245820', 'name': 'Mukesh J Bh...
# tt9033988  [{'imdb_id': 'nm0451174', 'name': 'Arshad Wars...
# tt9041222  [{'imdb_id': 'nm0219946', 'name': 'Ramesh Deo'...
# tt9042282  [{'imdb_id': 'nm9823727', 'name': 'Vaishali Ba...
# tt9042528                                                 []
# tt9043760  [{'imdb_id': 'nm5013143', 'name': 'Mohit Sehga...
# tt9044000  [{'imdb_id': 'nm6633459', 'name': 'Geeta', 'li...
# tt9046206  [{'imdb_id': 'nm10148511', 'name': 'Madhu Sing...
# tt9052870  [{'imdb_id': 'nm3601766', 'name': 'Shraddha Ka...
# tt9052936  [{'imdb_id': 'nm0219971', 'name': 'Sunny Deol'...
# tt9052942                                                 []
# tt9052946  [{'imdb_id': 'nm0006795', 'name': 'Salman Khan...
# tt9052958                                                 []
# tt9052960  [{'imdb_id': 'nm0451307', 'name': 'Saif Ali Kh...
# tt9052964  [{'imdb_id': 'nm0332871', 'name': 'Govinda', '...
# tt9053392                                                 []
# tt9055312  [{'imdb_id': 'nm1064764', 'name': 'Hrishitaa B...
# tt9056988  [{'imdb_id': 'nm0324744', 'name': 'Ramesh Goya...
# tt9059202  [{'imdb_id': 'nm10156491', 'name': 'Meenu Kawa...
# tt9060700  [{'imdb_id': 'nm10150444', 'name': 'Krishna Ga...
#
# [9857 rows x 14 columns]

# %%
movies_detail.shape
# Out:
# (9857, 14)

# %%
movies_list['imdb_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/bollywood/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'imdb_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-4a97ea5abb1e> in <module>
# ----> 1 movies_list['imdb_id']
#
# ~/anaconda3/envs/bollywood/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/envs/bollywood/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/bollywood/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/envs/bollywood/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/bollywood/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'imdb_id'

# %% [markdown]
# ### Selecting data
#
# pandas has two main containers, `Series` and `DataFrame`. You can think as a `DataFrame` as the content of a spreadsheet, or a SQL table. And `Series` as one of its columns.
#
# More formally, a `DataFrame` is a 2-dimensional structure, where each element is labelled both by its column and its row.
#
# | Movie | Year | Genre |
# | --- | --- | --- |
# | **PK** | 2014 | Comedy |
# | **Kabhi Khushi Kabhie Gham...** | 2001 | Drama |
# | **3 idiots** | 2009 | Comedy |
#
# As you can see in the example, every value can be defined by its position based on its labels. For example, the value at `PK`/`Genre` is `Comedy`. In pandas, this would be `movies.loc['PK', 'Genre']`.
#
# Also, every value cab be defined by its position. For example, in the second row, and first column, the value is `2001`. In pandas this would be `movies.iloc[1, 0]` (remember that in Python, the first index is `0`, the second is `1`...)
#
# **Exercise:** Can you obtain the value in the column `storyline`, and the row `tt2905838` in the movies `DataFrame`. Can you guess which is the movie? :)

# %% [markdown]
# To select a whole column from a `DataFrame` (which will be a `Series`) we can use `movies['rating']` (like getting a value from a `dict`). If the name of the column does not contain special characters, we can also use `movies.rating` (like for a class attribute or a `namedtuple`).
#
# Then, we can perform operations with the resulting `Series`:
# - Compute the maximum, the minimum, the median, or any other provided statistic:
#    - `movies['rating'].min()`
#    - `movies['rating'].max()`
#    - `movies['rating'].median()`
# - Double the rating of each movie (if we feel generous): `movies['rating'] * 2`
# - Make comparisons: `movies['rating'] > .8` (this will return a `Series` with `True` and `False` values, depending on whether the condition is satisfied in each row)
#
# The last point is quite important, as boolean `Series` can be used to filter the data. The syntax is `movies[condition]` where condition is a `Series` or boolean values. Note that the syntax is the same as `movies[column_name]`, and pandas will check what is the type and size of what is between the squared brackets, to decide whether to return a column, or a filtered `DataFrame`.
#
# **Exercise:** Return all the movies that have a rating greater than `9.5` and that their their title starts by the letter `K` (most Python string functions and methods can be applied to a `Series` by using `Series.str.<func-name>`).

# %% [markdown]
# ### Checking data
#
# In the dataset, we can see that both original `DataFrame` objects had a column for the user rating of the movies, `rate` and `rating`. This information may be redundant, but is worth comparing that they have the same values.
#
# **Exercise:** Compare whether there are differences in the two columns, and keep a single column with the information that makes more sense. To delete columns, `DataFrame` provides a method `.drop()`, or it is also possible to use `del movies['rating']`

# %% [markdown]
# ### Extracting information
#
# There is some information that needs to be transformed before we can use it. For example, the column with the number of votes. If you take a look, you can see how instead of having the number of votes as a number, the column contains a string including thousand separators (e.g. `1,000`). This is how it was presented in the original source.
#
# But this format is not appropiate to do operations. For example, if we want to check the smallest (`.min()`) or the largest (`.max()`) number of votes in our data, we're not getting the right results. This is because when dealing with strings, `'9'` is greater than `'10'` in the same was `z` is "greater" than `ab`.
#
# **Exercises:**
# 1. Create a new column `rating_votes` with the number of votes converted as a number. The first step is to get a string representation that does not contain the commas. This can be done with the method `.str.replace()`, replacing the commas with empty strings. Second is to convert the column type, from a Python object to a float representation. This can be done with the method `.astype()`.
#
# 1. Get the smallest and largest values for the number of votes.
#
# 1. Check how many missing values we have in the data (pandas provides the methods `.isnull()` and `.notnull()`). Remember that in Python, `True == 1` and `False == 0`, so you can sum `True` and `False` values.

# %% [markdown]
# Another column that we need to preprocess before we use it in a meaningful way is the `release_date`. In this case, the best way to do it is probably with regular expressions. Regular expressions define a pattern that is used to extract data that matches it. In pandas, it's possible to extract data based on regular expressions with the method `.str.extract()`.
#
# Some basics of regular expressions:
# - To mark the beginning of the string use `^`, and `$` for the end.
# - A digit (0 to 9) is matched by `\d`
# - To match specific characters a range can be defined, for example `[a-z]` would match all lower case letters. They can be combined, like in `[a-zA-Z]`.
# - To match several patterns of the same type, `*` can be used if the pattern is optional, and `+` if at least one character needs to be matched. For example `a+` would match `a`, `aa`, `aaa`...
# - To match the exact number of characters, curly brackets can be used, for example `a{4}` would match `aaaa`.
#
# **Exercise:** Write a regular expression that extracts the date from the `release_date` column. A string containing a date can be converted to a date type in pandas with `pandas.to_datetime()`

# %% [markdown]
# Finally, the last column that we want to preprocess is the duration of the movie. To operate with this column, once more we need it to be a numeric column, and not a string.
#
# **Exercise:** Replace the column `runtime` by a numerical column with the number of minutes extracted from the original column.

# %% [markdown]
# ### Save data
#
# Finally, in order to persist the data that we have created (by transforming the original data), we can export it. There are many formats supported by `pandas`, they are listed here:
# - https://pandas.pydata.org/pandas-docs/stable/api.html#id12
#
# The type of format used will depend on the case. Here there are some examples:
# - csv: When we want to open the data with a spreadsheet (discourage in other cases, as it looses type information, and it's inefficient)
# - json: When there are complex data structures we want to preserve (like `list`, `dict`...)
# - hdf and parquet: When we want to save the data in an efficient way (consume less storage and load faster)
#
# **Exercise:** Save the data as JSON. Try saving just couple of rows first, with different values of `orient`, to see which one looks more appropriate. Also test how the parameter `lines` affects the output.
