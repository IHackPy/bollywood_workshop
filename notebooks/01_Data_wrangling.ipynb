# %% [markdown]
# https://www.imdb.com/search/title?title_type=feature&release_date=1970-01-01,&countries=in&languages=hi&page=1

# %%
import pandas

movies = pandas.read_json('data/movie_info_from_list.jl', lines=True)

# %%
movies.head()
# Out:
#                                                 cast certificate  \
# 0  [{'name': 'Reema Kagti', 'link': '/name/nm1030...         12A
# 1  [{'name': 'Amar Kaushik', 'link': '/name/nm360...          15
# 2  [{'name': 'R. Balki', 'link': '/name/nm2669564...       PG-13
# 3  [{'name': 'Nitesh Tiwari', 'link': '/name/nm43...   Not Rated
# 4  [{'name': 'Rajkumar Hirani', 'link': '/name/nm...       PG-13
#
#                       genre  gross  \
# 0     Drama, History, Sport    NaN
# 1            Comedy, Horror    NaN
# 2          Biography, Drama    1.0
# 3  Action, Biography, Drama    1.0
# 4             Comedy, Drama    6.0
#
#                                                image    imdb_id  \
# 0  https://m.media-amazon.com/images/G/01/imdb/im...  tt6173990
# 1  https://m.media-amazon.com/images/G/01/imdb/im...  tt8108202
# 2  https://m.media-amazon.com/images/G/01/imdb/im...  tt7218518
# 3  https://m.media-amazon.com/images/G/01/imdb/im...  tt5074352
# ...

# %%
# %matplotlib inline
movies.rating.dropna().hist(bins=100)

# %%
movies[movies.rating > 9.2]
# Out:
#                                                    cast certificate   genre  \
# 1832  [{'name': 'Kireet Khurana', 'link': '/name/nm0...        None   Drama
# 2006  [{'name': 'Dar Gai', 'link': '/name/nm9072016/...         12A   Drama
# 5904  [{'name': 'Mohan Babu', 'link': '/name/nm05959...        None  Action
# 6319  [{'name': 'Mohan Babu', 'link': '/name/nm05959...        None  Action
# 6990  [{'name': 'Anshul Sinha', 'link': '/name/nm966...        None   Drama
#
#       gross                                              image    imdb_id  \
# 1832    NaN  https://m.media-amazon.com/images/G/01/imdb/im...  tt5963908
# 2006    NaN  https://m.media-amazon.com/images/G/01/imdb/im...  tt7028460
# 5904    NaN  https://m.media-amazon.com/images/G/01/imdb/im...  tt4946222
# 6319    NaN  https://m.media-amazon.com/images/G/01/imdb/im...  tt4944418
# 6990    NaN  https://m.media-amazon.com/images/G/01/imdb/im...  tt8080354
#
#                                   link  rating  runtime  \
# ...
